# %% [markdown]
# One Numeric Variable

# %% [markdown]
# Histogram

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
URL = "https://raw.githubusercontent.com/holtzy/data_to_viz/master/Example_dataset/1_OneNum.csv"
data = pd.read_csv(URL)
data
# Out:
#       price
# 0      75.0
# 1     104.0
# 2     369.0
# 3     300.0
# 4      92.0
# ...     ...
# 9990   97.0
# 9991   58.0
# 9992  127.0
# 9993  143.0
# 9994  132.0
#
# [9995 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(6, 8))
ax.set_xlim(0,300)
sns.histplot(data.price, bins=1000,ax=ax)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
fig, ax = plt.subplots(figsize=(6, 8))
ax.set_xlim(0,300)
sns.histplot(data.price, bins=3000,ax=ax)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %% [markdown]
# Density Plot

# %%
fig, ax = plt.subplots(figsize=(6, 8))
sns.kdeplot(data.price, x="price", ax = ax, bw_adjust=1, fill=True, cut =10)
ax.set_xlim(0, 1000)
# Out:
# (0.0, 1000.0)

# %%
fig, ax = plt.subplots(figsize=(6, 8))
sns.kdeplot(data.price, x="price", ax = ax, bw_adjust=0.05, fill=True, cut =2)
ax.set_xlim(0, 1000)
# Out:
# (0.0, 1000.0)

# %% [markdown]
# Two Numeric

# %% [markdown]
# Ordered

# %% [markdown]
# Line Plot

# %%
URL = "https://raw.githubusercontent.com/holtzy/data_to_viz/master/Example_dataset/3_TwoNumOrdered.csv"
df = pd.read_csv(URL)
df
# Out:
#               date value
# 0      2013-04-28 135.98
# 1      2013-04-29 147.49
# 2      2013-04-30 146.93
# 3      2013-05-01 139.89
# 4       2013-05-02 125.6
# ...                  ...
# 1817  2018-04-19 8298.69
# 1818  2018-04-20 8880.23
# 1819  2018-04-21 8997.57
# 1820  2018-04-22 9001.64
# 1821  2018-04-23 8958.55
#
# [1822 rows x 1 columns]

# %% [markdown]
# NOT ORDERED

# %% [markdown]
# FEW POINTS

# %% [markdown]
# SCATTER PLOT

# %%
URL = "https://raw.githubusercontent.com/holtzy/data_to_viz/master/Example_dataset/2_TwoNum.csv"
df = pd.read_csv(URL)
df
# Out:
#       GrLivArea  SalePrice
# 0          1710     208500
# 1          1262     181500
# 2          1786     223500
# 3          1717     140000
# 4          2198     250000
# ...         ...        ...
# 1455       1647     175000
# 1456       2073     210000
# 1457       2340     266500
# 1458       1078     142125
# 1459       1256     147500
#
# [1460 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(8,10))
sns.scatterplot(data=df, x="GrLivArea", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %% [markdown]
# THREE NUMERIC VARIABLES

# %% [markdown]
# NOT ORDERED

# %% [markdown]
# BUBBLE PLOT

# %%
URL = "https://raw.githubusercontent.com/holtzy/data_to_viz/master/Example_dataset/4_ThreeNum.csv"
df = pd.read_csv(URL)
df
# Out:
#                 country continent  lifeExp       pop     gdpPercap
# 0           Afghanistan      Asia   43.828  31889923    974.580338
# 1               Albania    Europe   76.423   3600523   5937.029526
# 2               Algeria    Africa   72.301  33333216   6223.367465
# 3                Angola    Africa   42.731  12420476   4797.231267
# 4             Argentina  Americas   75.320  40301927  12779.379640
# ..                  ...       ...      ...       ...           ...
# 137             Vietnam      Asia   74.249  85262356   2441.576404
# 138  West Bank and Gaza      Asia   73.422   4018332   3025.349798
# 139         Yemen, Rep.      Asia   62.698  22211743   2280.769906
# 140              Zambia    Africa   42.384  11746035   1271.211593
# 141            Zimbabwe    Africa   43.487  12311143    469.709298
#
# [142 rows x 5 columns]

# %%
import plotly.graph_objects as px
import numpy as np
x = df["lifeExp"]
y = df["gdpPercap"]
